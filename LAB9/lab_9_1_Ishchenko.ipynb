# %% [raw]
#  Префікс-функція (π[i]): Довжина найдовшого власного префікса рядка, який також є суфіксом для підрядка, що закінчується на позиції i.
# - Z-функція (Z[i]): Довжина найдовшого підрядка, починаючи з позиції i, який збігається з префіксом рядка.
# Різниця: Префікс-функція показує збіги з суфіксами, а Z-функція — збіги з префіксами, але з різних позицій у рядку.

# %% [raw]
# Z-функція використовується для визначення префіксних збігів у рядку. Вона ефективно допомагає у вирішенні задач таких як:
# - Пошук підрядка у рядку.
# - Підрахунок кількості різних підрядків.
# - Стиснення рядків.

# %% [raw]
#  Динамічне програмування: Таблиця dp[i][j] зберігає довжину найдовшого спільного підрядка, що закінчується в s1[i-1] і s2[j-1]. Складність O(n * m).
# - Суфіксні масиви: Побудова суфіксних масивів для обох рядків і знаходження найдовшого збігу. Складність O(n log n + m log m).

# %% [raw]
#  Динамічне програмування: Таблиця dp[i][j] зберігає довжину найдовшого спільного підрядка, що закінчується в s1[i-1] і s2[j-1]. Складність O(n * m).
# - Суфіксні масиви: Побудова суфіксних масивів для обох рядків і знаходження найдовшого збігу. Складність O(n log n + m log m).

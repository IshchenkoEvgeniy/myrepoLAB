# %% [raw]
#  Бінарне дерево пошуку (BST) – це тип бінарного дерева, де кожен вузол має значення більше за всі значення у його лівому піддереві і менше за всі значення у його правому піддереві. Бінарне дерево не має таких обмежень на розміщення вузлів.

# %% [raw]
#   - Бінарна купа – це повне бінарне дерево, яке задовольняє властивість купи: у мін-купі кожен батьківський вузол менший або рівний своїм дочірнім вузлам, у макс-купі – більший або рівний. У звичайному бінарному дереві такі властивості не обов’язкові.

# %% [raw]
# - Бінарне дерево: Кожен вузол має не більше двох дочірніх вузлів.
#    - Бінарне дерево пошуку (BST): Вузли організовані для ефективного пошуку, вставки та видалення.
#    - АВЛ-дерево: Самобалансоване бінарне дерево пошуку, де висота лівого і правого піддерев відрізняється не більше ніж на 1.
#    - Червоний-чорний дерево: Самобалансоване бінарне дерево пошуку з додатковими властивостями, що обмежують довжину шляхів.
#    - Б-дерево: Збалансоване дерево для зберігання даних на диску, використовується в базах даних.
#    - Trie: Префіксне дерево для ефективного зберігання та пошуку рядків.

# %% [raw]
#  - Пошук: Використання BST для швидкого пошуку елементів.
#    - Сортування: Використання структури як heapsort.
#    - Автозаповнення: Використання Trie для пошуку префіксів.
#    - Обробка виразів: Використання дерев для побудови синтаксичних дерев.

# %% [raw]
#  - Організація: Купа – це повне бінарне дерево, де кожен батьківський вузол відповідає властивості купи.
#    - Додавання: Вставляємо елемент у кінці дерева (останнє місце), а потім виконуємо "просіювання вгору" для відновлення властивості купи.
#    - Вилучення: Заміщуємо корінь останнім елементом, видаляємо останній елемент, а потім виконуємо "просіювання вниз" для відновлення властивості купи.

# %% [raw]
#  Задача про k-й найбільший елемент: Знаходження k-го найбільшого елемента у масиві.
#    - Планувальник задач: Вибір завдання з найвищим пріоритетом.
#    - Алгоритми сортування: Реалізація heapsort.
#    - Алгоритми пошуку найкоротшого шляху: Використання пріоритетної черги у алгоритмах Дейкстри та Прима.

# %% [raw]
#  - Геш-функція перетворює ключ у індекс масиву, де зберігається значення. Для пошуку значення, геш-функція обчислює індекс ключа, за яким знаходиться потрібне значення.

# %% [raw]
# Ланцюжкове хешування: Використання списків для зберігання всіх елементів, що мають один і той же геш-індекс.
#      - Переваги: Проста реалізація, добре працює з різнорідними даними.
#      - Недоліки: Займає більше пам’яті через додаткові структури даних.
#    - Відкрита адресація: Пошук вільного місця у хеш-таблиці за визначеними правилами (лінійне пробування, квадратичне пробування, подвійне хешування).
#      - Переваги: Використовує менше пам’яті, оскільки не потребує додаткових структур даних.
#      - Недоліки: Може призводити до кластеризації та збільшення часу пошуку у випадку високої заповненості таблиці.

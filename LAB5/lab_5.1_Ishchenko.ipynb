# %% [raw]
# Задача пошуку полягає в знаходженні певного елемента в масиві або структурі даних

# %% [raw]
#  Критерії для оцінювання ефективності алгоритмів пошуку включають часову складність, просторову складність, стабільність, та стійкість до помилок

# %% [raw]
# Лінійний пошук - це метод перебору елементів масиву з початку до кінця до знаходження цільового елемента, з асимптотичною складністю  O(n)

# %% [raw]
#  Бінарний пошук - це метод для знаходження елемента в відсортованому масиві шляхом послідовного поділу інтервалу пошуку навпіл, з асимптотичною складністю  O log n

# %% [raw]
# Переваги бінарного пошуку включають значно меншу кількість порівнянь в великих масивах, однак його недоліком є вимога відсортованості масиву, що додає додаткову обчислювальну вартість для попереднього сортування

# %% [raw]
# Окрім лінійного і бінарного пошуку, існують також інші алгоритми пошуку, такі як інтерполяційний пошук, експоненціальний пошук, та хеш-пошук
